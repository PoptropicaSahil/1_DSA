# %% [markdown]
# ## Ref [Leetcode sheet](https://leetcode.com/explore/interview/card/cheatsheets/720/resources/4723/)

# %%
# /two pointers

def fn(arr):
    left = 0
    right = len(arr) - 1

    while left < right:
        # logic here
        if condition: left += 1
        else: right -= 1

    return left

# %%
# two pointers two inputs exhaust both

# sliding window
def fn(arr):
    left = 0
    curr = 0

    for right in range(len(arr)):
        # logic here 
        # mostly add arr[right] to curr

        while window_condition_broken:
            # remove arr[left] from curr
            left += 1
        
    return ans

# %%
# build a prefix sum

def fn(arr):
    prefix = [arr[0]]

    for i in range(1, len(arr)):
        prefix.append(prefix[-1] + arr[i])

    return prefix

# %%
# efficient string building
"".join(['1', '2', '3', '4'])
# Out:
# '1234'

# %%
# fast and slow pointer

def fn(arr):
    slow = head
    fast = head
    ans = 0

    while fast and fast.next:
        # some logic
        slow = slow.next
        fast = fast.next.next

    return ans

# %%
# reverse a linked list

def fn(head):
    prev = None
    cur = head

    while cur:
        next = cur.next
        cur.next = prev

        prev = cur
        cur = next

    return prev

# %%
# number of subarrays that fit an exact criteria
# sus

from collections import defaultdict

def fn(arr, target):

    # keys: sum value
    # values: count
    count = defaultdict(int)
    count[0] = 1 # one way to make 0 sum
    ans = 0
    cur = 0 # current cumumlative sum

    for num in arr:
        # logic to change cur
        ans += count[cur - target] # ans is updated by number of times (cur-target) was seen
        cur += num # update the current cumulative sum
        count[cur] += 1

    return ans

# %%
# dfs recursive

def dfs(root):
    if not root:
        return
    
    ans = 0
    # do logic

    dfs(root.left)
    dfs(root.right)

    return ans

# %%
# dfs iterative

def dfs(root):
    stack = [root]
    ans = 0

    while stack:
        node = stack.pop()
        # do logic

        if node.left:
            stack.append(node.left)
        if node.right:
            stack.append(node.right)
        
    return ans

# %%
# dfs iterative

from collections import deque

def bfs(root):
    queue = deque([root])
    ans = 0

    while queue:
        node = queue.popleft()
        # do logic

        if node.left:
            queue.append(node.left)
        if node.right:
            queue.append(node.right)
        
    return ans
