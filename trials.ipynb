# %%
l1 = [[2, 1, 1], [1, 1, 0], [0, 1, 1]]

# %%
l2 = l1.copy()

# %%
l3 = l1[:]

# %%
l1[1][1] = 3

# %%
l1, l2,l3
# Out:
# ([[2, 1, 1], [1, 3, 0], [0, 1, 1]],
#  [[2, 1, 1], [1, 3, 0], [0, 1, 1]],
#  [[2, 1, 1], [1, 3, 0], [0, 1, 1]])

# %%
arr = [1,2,3,4]

# %%
arr.insert(2, 45)

# %%
arr
# Out:
# [1, 2, 45, 3, 4]

# %%
from typing import List

class Solution:
    def merge(self, nums1: List[int], m: int, nums2: List[int], n: int) -> None:
        """
        Do not return anything, modify nums1 in-place instead.
        """

        # if not nums1:
        #     return nums2
        
        # if not nums2:
        #     return nums1

        i, j = 0, 0

        while j <= n:
            
            print(f'i = {i} j= {j} nums1 ={nums1}')

            if nums1[i] <= nums2[j] <= nums1[i+1]:
                nums1.insert(i+1, nums2[j])
                j += 1
                i += 1
            
            elif i > m and i < m + n:
                nums1.insert(i+j-1, nums2[j])
                j += 1
                i += 1

            elif i == m + n:
                return

            else:
                i += 1
            
            
            print(f'\t i = {i} j= {j} nums1 ={nums1}')


Solution().merge([1,2,4,0,0,0], 3, [3,5,6], 3)
# Out:
# i = 0 j= 0 nums1 =[1, 2, 4, 0, 0, 0]
# 	 i = 1 j= 0 nums1 =[1, 2, 4, 0, 0, 0]
# i = 1 j= 0 nums1 =[1, 2, 4, 0, 0, 0]
# 	 i = 2 j= 1 nums1 =[1, 2, 3, 4, 0, 0, 0]
# i = 2 j= 1 nums1 =[1, 2, 3, 4, 0, 0, 0]
# 	 i = 3 j= 1 nums1 =[1, 2, 3, 4, 0, 0, 0]
# i = 3 j= 1 nums1 =[1, 2, 3, 4, 0, 0, 0]
# 	 i = 4 j= 1 nums1 =[1, 2, 3, 4, 0, 0, 0]
# i = 4 j= 1 nums1 =[1, 2, 3, 4, 0, 0, 0]
# 	 i = 5 j= 2 nums1 =[1, 2, 3, 4, 5, 0, 0, 0]
# i = 5 j= 2 nums1 =[1, 2, 3, 4, 5, 0, 0, 0]
# 	 i = 6 j= 3 nums1 =[1, 2, 3, 4, 5, 0, 6, 0, 0]
# i = 6 j= 3 nums1 =[1, 2, 3, 4, 5, 0, 6, 0, 0]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 41
#      35                 i += 1
#      38             print(f'\t i = {i} j= {j} nums1 ={nums1}')
# ---> 41 Solution().merge([1,2,4,0,0,0], 3, [3,5,6], 3)
#
# Cell In[24], line 21, in Solution.merge(self, nums1, m, nums2, n)
#      17 while j <= n:
#      19     print(f'i = {i} j= {j} nums1 ={nums1}')
# ---> 21     if nums1[i] <= nums2[j] <= nums1[i+1]:
#      22         nums1.insert(i+1, nums2[j])
#      23         j += 1
#
# IndexError: list index out of range
